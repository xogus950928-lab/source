# %%
head = "python"
head
# Out:
# 'python'

# %%
# 인덱싱
a=[]
b=[1,3,5,7,9]
c=list()
d=[]

# %%
a=[1,4,2,3]
a.sort()
a
# Out:
# [1, 2, 3, 4]

# %%
#index()
a.index(2)
# Out:
# 1

# %%
t1=()
t2=(1,)
t3=1,2,3
t4=(1,2,3)
t5=('a','b',('ab','cd'))

# %%
print(t2+t3)
print(t2*3)
# Out:
# (1, 1, 2, 3)
# (1, 1, 1)

# %%
dict1={"name":"Kim","age":22}
dict2={1:"Kim", 2:22, 3:"서울"}
dict3={"arr":[1,2,3,4,5]}

# %%
dict1['rank']=[15,17,19]
dict1
# Out:
# {'name': 'Kim', 'age': 22, 'rank': [15, 17, 19]}

# %%
print(dict1.keys())
print(dict1.values())
print(dict1.items())
# Out:
# dict_keys(['name', 'age', 'rank'])
# dict_values(['Kim', 22, [15, 17, 19]])
# dict_items([('name', 'Kim'), ('age', 22), ('rank', [15, 17, 19])])

# %%
money=5000
if money>=10000:
    print("택시 타기")

# %%
if money>=10000:
    print("택시 타기")
else:
    print("버스 타기")
# Out:
# 버스 타기

# %%
jumsu=88
if jumsu>=90:
    print("A")
elif jumsu>=80:
    print("B")    
elif jumsu>=70:
    print("C")
else :
    print("D")
# Out:
# B

# %%
a='99'
b=98
#print(a>=90)
print(type(a))
print(type(b))
a=int(a)
# Out:
# <class 'str'>
# <class 'int'>

# %%
#숫자를 입력받은 후, 홀 짝 구분
num=int(input("숫자 입력"))
if num % 2 ==0:
    print("짝수")
else:
    print("홀수")
# Out:
# '58'
